# %%
def game_core_v5(number):
    
    count = 1
    predict = 100  
    left = 0
    right = 101
    '''Бесконечный цикл с бинарным поиском.'''
    while True: 
        if number < predict:
            right = predict + 1
        elif number > predict:
            left = predict - 1
        else:
            break
        count += 1
        predict = (left+right)//2
    '''Вывод результатов предсказания для контроля.'''    
    if number == predict: 
        print('Было загадано число', predict)
    else:
        print('Ошибка!')
    '''Возвращение числа попыток.'''    
    return count 
    
            
def score_game(game_core):
    '''Запускаем игру 1000 раз, чтобы узнать, как быстро игра угадывает число'''
    import numpy as np
    count_ls = []
    np.random.seed(1)  # фиксируем RANDOM SEED, чтобы ваш эксперимент был воспроизводим!
    random_array = np.random.randint(1,101, size=(1000))
    for number in random_array:
        count_ls.append(game_core(number))
    score = int(np.mean(count_ls))
    print(f"Ваш алгоритм угадывает число в среднем за {score} попыток")
    
    
score_game(game_core_v5)
# Out:
# Было загадано число 38
# Было загадано число 13
# Было загадано число 73
# Было загадано число 10
# Было загадано число 76
# Было загадано число 6
# Было загадано число 80
# Было загадано число 65
# Было загадано число 17
# Было загадано число 2
# Было загадано число 77
# Было загадано число 72
# Было загадано число 7
# Было загадано число 26
# Было загадано число 51
# Было загадано число 21
# Было загадано число 19
# Было загадано число 85
# Было загадано число 12
# Было загадано число 29
# Было загадано число 30
# Было загадано число 15
# Было загадано число 51
# Было загадано число 69
# Было загадано число 88
# Было загадано число 88
# Было загадано число 95
# Было загадано число 97
# Было загадано число 87
# Было загадано число 14
# Было загадано число 10
# Было загадано число 8
# Было загадано число 64
# Было загадано число 62
# Было загадано число 23
# Было загадано число 58
# Было загадано число 2
# Было загадано число 1
# Было загадано число 61
# Было загадано число 82
# Было загадано число 9
# Было загадано число 89
# Было загадано число 14
# Было загадано число 48
# Было загадано число 73
# Было загадано число 31
# Было загадано число 72
# Было загадано число 4
# Было загадано число 71
# Было загадано число 22
# Было загадано число 50
# Было загадано число 58
# Было загадано число 4
# Было загадано число 69
# Было загадано число 25
# Было загадано число 44
# Было загадано число 77
# Было загадано число 27
# Было загадано число 53
# Было загадано число 81
# Было загадано число 42
# Было загадано число 83
# Было загадано число 16
# Было загадано число 65
# Было загадано число 69
# Было загадано число 26
# Было загадано число 99
# Было загадано число 88
# Было загадано число 8
# Было загадано число 27
# Было загадано число 26
# Было загадано число 23
# Было загадано число 10
# Было загадано число 68
# Было загадано число 24
# Было загадано число 28
# Было загадано число 38
# Было загадано число 58
# Было загадано число 84
# Было загадано число 39
# Было загадано число 9
# Было загадано число 33
# Было загадано число 35
# Было загадано число 11
# Было загадано число 24
# Было загадано число 16
# Было загадано число 88
# Было загадано число 26
# Было загадано число 72
# Было загадано число 93
# Было загадано число 75
# Было загадано число 63
# Было загадано число 47
# Было загадано число 33
# Было загадано число 89
# Было загадано число 24
# Было загадано число 56
# Было загадано число 66
# Было загадано число 78
# Было загадано число 4
# Было загадано число 1
# Было загадано число 78
# Было загадано число 7
# Было загадано число 53
# Было загадано число 86
# Было загадано число 71
# Было загадано число 3
# Было загадано число 77
# Было загадано число 92
# Было загадано число 22
# Было загадано число 76
# Было загадано число 8
# Было загадано число 78
# Было загадано число 73
# Было загадано число 76
# Было загадано число 77
# Было загадано число 44
# Было загадано число 21
# Было загадано число 31
# Было загадано число 37
# Было загадано число 8
# Было загадано число 46
# Было загадано число 69
# Было загадано число 58
# Было загадано число 83
# Было загадано число 97
# Было загадано число 14
# Было загадано число 11
# Было загадано число 24
# Было загадано число 82
# Было загадано число 8
# Было загадано число 25
# Было загадано число 75
# Было загадано число 93
# Было загадано число 21
# Было загадано число 33
# Было загадано число 13
# Было загадано число 66
# Было загадано число 95
# Было загадано число 61
# Было загадано число 25
# Было загадано число 83
# Было загадано число 98
# Было загадано число 3
# Было загадано число 93
# Было загадано число 99
# Было загадано число 11
# Было загадано число 55
# Было загадано число 97
# Было загадано число 83
# Было загадано число 87
# Было загадано число 71
# Было загадано число 67
# Было загадано число 72
# Было загадано число 49
# Было загадано число 55
# Было загадано число 16
# Было загадано число 6
# Было загадано число 18
# Было загадано число 43
# Было загадано число 21
# Было загадано число 49
# Было загадано число 23
# Было загадано число 14
# Было загадано число 98
# Было загадано число 54
# Было загадано число 85
# Было загадано число 11
# Было загадано число 97
# Было загадано число 56
# Было загадано число 62
# Было загадано число 57
# Было загадано число 90
# Было загадано число 22
# Было загадано число 97
# Было загадано число 84
# Было загадано число 26
# Было загадано число 15
# Было загадано число 14
# Было загадано число 85
# Было загадано число 44
# Было загадано число 7
# Было загадано число 78
# Было загадано число 57
# Было загадано число 60
# Было загадано число 16
# Было загадано число 25
# Было загадано число 10
# Было загадано число 67
# Было загадано число 72
# Было загадано число 54
# Было загадано число 70
# Было загадано число 37
# Было загадано число 22
# Было загадано число 41
# Было загадано число 78
# Было загадано число 92
# Было загадано число 50
# Было загадано число 48
# Было загадано число 78
# Было загадано число 41
# Было загадано число 79
# Было загадано число 46
# Было загадано число 88
# Было загадано число 17
# Было загадано число 29
# Было загадано число 46
# Было загадано число 68
# Было загадано число 67
# Было загадано число 79
# Было загадано число 47
# Было загадано число 1
# Было загадано число 30
# Было загадано число 64
# Было загадано число 76
# Было загадано число 36
# Было загадано число 54
# Было загадано число 94
# Было загадано число 34
# Было загадано число 3
# Было загадано число 85
# Было загадано число 84
# Было загадано число 49
# Было загадано число 55
# Было загадано число 33
# Было загадано число 29
# Было загадано число 56
# Было загадано число 83
# Было загадано число 32
# Было загадано число 29
# Было загадано число 95
# Было загадано число 75
# Было загадано число 9
# Было загадано число 100
# Было загадано число 33
# Было загадано число 9
# Было загадано число 85
# Было загадано число 78
# Было загадано число 51
# Было загадано число 80
# Было загадано число 42
# Было загадано число 65
# Было загадано число 84
# Было загадано число 25
# Было загадано число 21
# Было загадано число 45
# Было загадано число 16
# Было загадано число 31
# Было загадано число 92
# Было загадано число 15
# Было загадано число 20
# Было загадано число 27
# Было загадано число 87
# Было загадано число 8
# Было загадано число 100
# Было загадано число 54
# Было загадано число 48
# Было загадано число 61
# Было загадано число 35
# Было загадано число 33
# Было загадано число 20
# Было загадано число 68
# Было загадано число 25
# Было загадано число 84
# Было загадано число 95
# Было загадано число 39
# Было загадано число 48
# Было загадано число 6
# Было загадано число 80
# Было загадано число 64
# Было загадано число 88
# Было загадано число 33
# Было загадано число 43
# Было загадано число 75
# Было загадано число 67
# Было загадано число 89
# Было загадано число 99
# Было загадано число 31
# Было загадано число 18
# Было загадано число 69
# Было загадано число 65
# Было загадано число 61
# Было загадано число 79
# Было загадано число 18
# Было загадано число 40
# Было загадано число 36
# Было загадано число 82
# Было загадано число 29
# Было загадано число 23
# Было загадано число 39
# Было загадано число 42
# Было загадано число 75
# Было загадано число 78
# Было загадано число 71
# Было загадано число 26
# Было загадано число 49
# Было загадано число 51
# Было загадано число 63
# Было загадано число 45
# Было загадано число 55
# Было загадано число 1
# Было загадано число 87
# Было загадано число 17
# Было загадано число 20
# Было загадано число 10
# Было загадано число 93
# Было загадано число 52
# Было загадано число 11
# Было загадано число 69
# Было загадано число 24
# Было загадано число 15
# Было загадано число 64
# Было загадано число 22
# Было загадано число 47
# Было загадано число 4
# Было загадано число 57
# Было загадано число 89
# Было загадано число 81
# Было загадано число 47
# Было загадано число 55
# Было загадано число 80
# Было загадано число 72
# Было загадано число 15
# Было загадано число 78
# Было загадано число 16
# Было загадано число 26
# Было загадано число 54
# Было загадано число 85
# Было загадано число 59
# Было загадано число 86
# Было загадано число 30
# Было загадано число 45
# Было загадано число 38
# Было загадано число 23
# Было загадано число 92
# Было загадано число 55
# Было загадано число 77
# Было загадано число 13
# Было загадано число 60
# Было загадано число 27
# Было загадано число 77
# Было загадано число 72
# Было загадано число 88
# Было загадано число 40
# Было загадано число 44
# Было загадано число 77
# Было загадано число 39
# Было загадано число 92
# Было загадано число 70
# Было загадано число 99
# Было загадано число 34
# Было загадано число 44
# Было загадано число 27
# Было загадано число 57
# Было загадано число 70
# Было загадано число 74
# Было загадано число 53
# Было загадано число 90
# Было загадано число 28
# Было загадано число 44
# Было загадано число 2
# Было загадано число 83
# Было загадано число 95
# Было загадано число 97
# Было загадано число 27
# Было загадано число 85
# Было загадано число 31
# Было загадано число 65
# Было загадано число 23
# Было загадано число 99
# Было загадано число 53
# Было загадано число 4
# Было загадано число 71
# Было загадано число 13
# Было загадано число 40
# Было загадано число 84
# Было загадано число 49
# Было загадано число 62
# Было загадано число 71
# Было загадано число 14
# Было загадано число 37
# Было загадано число 24
# Было загадано число 23
# Было загадано число 67
# Было загадано число 93
# Было загадано число 96
# Было загадано число 54
# Было загадано число 10
# Было загадано число 42
# Было загадано число 58
# Было загадано число 89
# Было загадано число 94
# Было загадано число 77
# Было загадано число 83
# Было загадано число 12
# Было загадано число 37
# Было загадано число 17
# Было загадано число 31
# Было загадано число 85
# Было загадано число 58
# Было загадано число 36
# Было загадано число 42
# Было загадано число 82
# Было загадано число 3
# Было загадано число 86
# Было загадано число 94
# Было загадано число 37
# Было загадано число 47
# Было загадано число 81
# Было загадано число 28
# Было загадано число 73
# Было загадано число 29
# Было загадано число 3
# Было загадано число 100
# Было загадано число 14
# Было загадано число 42
# Было загадано число 37
# Было загадано число 41
# Было загадано число 19
# Было загадано число 98
# Было загадано число 39
# Было загадано число 64
# Было загадано число 47
# Было загадано число 90
# Было загадано число 3
# Было загадано число 99
# Было загадано число 29
# Было загадано число 79
# Было загадано число 76
# Было загадано число 59
# Было загадано число 43
# Было загадано число 27
# Было загадано число 22
# Было загадано число 59
# Было загадано число 17
# Было загадано число 93
# Было загадано число 38
# Было загадано число 12
# Было загадано число 23
# Было загадано число 7
# Было загадано число 97
# Было загадано число 15
# Было загадано число 88
# Было загадано число 76
# Было загадано число 36
# Было загадано число 64
# Было загадано число 33
# Было загадано число 92
# Было загадано число 50
# Было загадано число 1
# Было загадано число 23
# Было загадано число 98
# Было загадано число 71
# Было загадано число 37
# Было загадано число 19
# Было загадано число 28
# Было загадано число 29
# Было загадано число 53
# Было загадано число 95
# Было загадано число 51
# Было загадано число 47
# Было загадано число 8
# Было загадано число 86
# Было загадано число 17
# Было загадано число 30
# Было загадано число 12
# Было загадано число 62
# Было загадано число 15
# Было загадано число 31
# Было загадано число 9
# Было загадано число 41
# Было загадано число 49
# Было загадано число 31
# Было загадано число 24
# Было загадано число 67
# Было загадано число 93
# Было загадано число 65
# Было загадано число 13
# Было загадано число 18
# Было загадано число 34
# Было загадано число 11
# Было загадано число 29
# Было загадано число 76
# Было загадано число 6
# Было загадано число 82
# Было загадано число 6
# Было загадано число 43
# Было загадано число 87
# Было загадано число 53
# Было загадано число 58
# Было загадано число 57
# Было загадано число 79
# Было загадано число 88
# Было загадано число 82
# Было загадано число 11
# Было загадано число 73
# Было загадано число 49
# Было загадано число 20
# Было загадано число 13
# Было загадано число 26
# Было загадано число 78
# Было загадано число 17
# Было загадано число 5
# Было загадано число 89
# Было загадано число 28
# Было загадано число 51
# Было загадано число 69
# Было загадано число 4
# Было загадано число 59
# Было загадано число 13
# Было загадано число 3
# Было загадано число 77
# Было загадано число 97
# Было загадано число 97
# Было загадано число 62
# Было загадано число 16
# Было загадано число 75
# Было загадано число 13
# Было загадано число 19
# Было загадано число 31
# Было загадано число 60
# Было загадано число 6
# Было загадано число 17
# Было загадано число 96
# Было загадано число 97
# Было загадано число 61
# Было загадано число 44
# Было загадано число 32
# Было загадано число 100
# Было загадано число 45
# Было загадано число 25
# Было загадано число 63
# Было загадано число 80
# Было загадано число 22
# Было загадано число 20
# Было загадано число 78
# Было загадано число 34
# Было загадано число 5
# Было загадано число 40
# Было загадано число 68
# Было загадано число 35
# Было загадано число 35
# Было загадано число 43
# Было загадано число 79
# Было загадано число 83
# Было загадано число 39
# Было загадано число 49
# Было загадано число 82
# Было загадано число 6
# Было загадано число 92
# Было загадано число 9
# Было загадано число 41
# Было загадано число 70
# Было загадано число 6
# Было загадано число 8
# Было загадано число 79
# Было загадано число 38
# Было загадано число 79
# Было загадано число 34
# Было загадано число 28
# Было загадано число 52
# Было загадано число 78
# Было загадано число 31
# Было загадано число 44
# Было загадано число 47
# Было загадано число 10
# Было загадано число 68
# Было загадано число 4
# Было загадано число 68
# Было загадано число 55
# Было загадано число 98
# Было загадано число 64
# Было загадано число 100
# Было загадано число 81
# Было загадано число 29
# Было загадано число 38
# Было загадано число 65
# Было загадано число 38
# Было загадано число 94
# Было загадано число 19
# Было загадано число 79
# Было загадано число 71
# Было загадано число 93
# Было загадано число 53
# Было загадано число 11
# Было загадано число 33
# Было загадано число 47
# Было загадано число 64
# Было загадано число 94
# Было загадано число 19
# Было загадано число 37
# Было загадано число 30
# Было загадано число 40
# Было загадано число 29
# Было загадано число 55
# Было загадано число 30
# Было загадано число 56
# Было загадано число 91
# Было загадано число 28
# Было загадано число 61
# Было загадано число 13
# Было загадано число 18
# Было загадано число 72
# Было загадано число 92
# Было загадано число 8
# Было загадано число 84
# Было загадано число 57
# Было загадано число 52
# Было загадано число 33
# Было загадано число 77
# Было загадано число 63
# Было загадано число 52
# Было загадано число 97
# Было загадано число 31
# Было загадано число 23
# Было загадано число 6
# Было загадано число 92
# Было загадано число 96
# Было загадано число 23
# Было загадано число 77
# Было загадано число 23
# Было загадано число 19
# Было загадано число 94
# Было загадано число 30
# Было загадано число 19
# Было загадано число 53
# Было загадано число 32
# Было загадано число 50
# Было загадано число 99
# Было загадано число 84
# Было загадано число 94
# Было загадано число 46
# Было загадано число 52
# Было загадано число 87
# Было загадано число 16
# Было загадано число 72
# Было загадано число 49
# Было загадано число 29
# Было загадано число 84
# Было загадано число 28
# Было загадано число 44
# Было загадано число 20
# Было загадано число 80
# Было загадано число 71
# Было загадано число 89
# Было загадано число 87
# Было загадано число 12
# Было загадано число 66
# Было загадано число 94
# Было загадано число 16
# Было загадано число 52
# Было загадано число 99
# Было загадано число 87
# Было загадано число 46
# Было загадано число 64
# Было загадано число 43
# Было загадано число 23
# Было загадано число 83
# Было загадано число 41
# Было загадано число 45
# Было загадано число 17
# Было загадано число 18
# Было загадано число 89
# Было загадано число 1
# Было загадано число 98
# Было загадано число 83
# Было загадано число 72
# Было загадано число 15
# Было загадано число 37
# Было загадано число 27
# Было загадано число 33
# Было загадано число 2
# Было загадано число 49
# Было загадано число 89
# Было загадано число 23
# Было загадано число 35
# Было загадано число 95
# Было загадано число 22
# Было загадано число 69
# Было загадано число 68
# Было загадано число 49
# Было загадано число 19
# Было загадано число 98
# Было загадано число 12
# Было загадано число 12
# Было загадано число 53
# Было загадано число 77
# Было загадано число 69
# Было загадано число 46
# Было загадано число 65
# Было загадано число 90
# Было загадано число 41
# Было загадано число 8
# Было загадано число 8
# Было загадано число 34
# Было загадано число 59
# Было загадано число 8
# Было загадано число 35
# Было загадано число 5
# Было загадано число 6
# Было загадано число 62
# Было загадано число 51
# Было загадано число 77
# Было загадано число 46
# Было загадано число 97
# Было загадано число 22
# Было загадано число 93
# Было загадано число 72
# Было загадано число 93
# Было загадано число 26
# Было загадано число 98
# Было загадано число 2
# Было загадано число 14
# Было загадано число 39
# Было загадано число 86
# Было загадано число 28
# Было загадано число 39
# Было загадано число 85
# Было загадано число 34
# Было загадано число 2
# Было загадано число 32
# Было загадано число 39
# Было загадано число 29
# Было загадано число 76
# Было загадано число 100
# Было загадано число 32
# Было загадано число 52
# Было загадано число 67
# Было загадано число 68
# Было загадано число 33
# Было загадано число 75
# Было загадано число 33
# Было загадано число 98
# Было загадано число 6
# Было загадано число 1
# Было загадано число 38
# Было загадано число 73
# Было загадано число 44
# Было загадано число 25
# Было загадано число 17
# Было загадано число 97
# Было загадано число 97
# Было загадано число 42
# Было загадано число 25
# Было загадано число 22
# Было загадано число 28
# Было загадано число 47
# Было загадано число 36
# Было загадано число 63
# Было загадано число 69
# Было загадано число 63
# Было загадано число 33
# Было загадано число 46
# Было загадано число 89
# Было загадано число 43
# Было загадано число 58
# Было загадано число 26
# Было загадано число 33
# Было загадано число 34
# Было загадано число 7
# Было загадано число 66
# Было загадано число 52
# Было загадано число 32
# Было загадано число 8
# Было загадано число 14
# Было загадано число 4
# Было загадано число 29
# Было загадано число 16
# Было загадано число 30
# Было загадано число 67
# Было загадано число 62
# Было загадано число 84
# Было загадано число 97
# Было загадано число 59
# Было загадано число 83
# Было загадано число 35
# Было загадано число 31
# Было загадано число 58
# Было загадано число 97
# Было загадано число 50
# Было загадано число 47
# Было загадано число 84
# Было загадано число 42
# Было загадано число 21
# Было загадано число 41
# Было загадано число 51
# Было загадано число 5
# Было загадано число 10
# Было загадано число 1
# Было загадано число 91
# Было загадано число 22
# Было загадано число 75
# Было загадано число 22
# Было загадано число 34
# Было загадано число 39
# Было загадано число 38
# Было загадано число 44
# Было загадано число 34
# Было загадано число 96
# Было загадано число 42
# Было загадано число 72
# Было загадано число 70
# Было загадано число 71
# Было загадано число 24
# Было загадано число 87
# Было загадано число 40
# Было загадано число 32
# Было загадано число 38
# Было загадано число 39
# Было загадано число 57
# Было загадано число 88
# Было загадано число 29
# Было загадано число 37
# Было загадано число 67
# Было загадано число 11
# Было загадано число 85
# Было загадано число 1
# Было загадано число 17
# Было загадано число 31
# Было загадано число 4
# Было загадано число 79
# Было загадано число 60
# Было загадано число 54
# Было загадано число 70
# Было загадано число 50
# Было загадано число 75
# Было загадано число 47
# Было загадано число 28
# Было загадано число 34
# Было загадано число 73
# Было загадано число 69
# Было загадано число 40
# Было загадано число 33
# Было загадано число 98
# Было загадано число 8
# Было загадано число 34
# Было загадано число 63
# Было загадано число 15
# Было загадано число 78
# Было загадано число 44
# Было загадано число 62
# Было загадано число 86
# Было загадано число 37
# Было загадано число 13
# Было загадано число 54
# Было загадано число 27
# Было загадано число 83
# Было загадано число 100
# Было загадано число 13
# Было загадано число 100
# Было загадано число 26
# Было загадано число 2
# Было загадано число 42
# Было загадано число 56
# Было загадано число 56
# Было загадано число 65
# Было загадано число 16
# Было загадано число 93
# Было загадано число 41
# Было загадано число 61
# Было загадано число 71
# Было загадано число 50
# Было загадано число 51
# Было загадано число 33
# Было загадано число 91
# Было загадано число 21
# Было загадано число 53
# Было загадано число 39
# Было загадано число 66
# Было загадано число 81
# Было загадано число 58
# Было загадано число 53
# Было загадано число 90
# Было загадано число 20
# Было загадано число 95
# Было загадано число 65
# Было загадано число 43
# Было загадано число 48
# Было загадано число 22
# Было загадано число 98
# Было загадано число 2
# Было загадано число 90
# Было загадано число 39
# Было загадано число 13
# Было загадано число 19
# Было загадано число 78
# Было загадано число 78
# Было загадано число 89
# Было загадано число 91
# Было загадано число 84
# Было загадано число 40
# Было загадано число 99
# Было загадано число 16
# Было загадано число 38
# Было загадано число 97
# Было загадано число 37
# Было загадано число 99
# Было загадано число 2
# Было загадано число 33
# Было загадано число 31
# Было загадано число 8
# Было загадано число 51
# Было загадано число 51
# Было загадано число 33
# Было загадано число 44
# Было загадано число 42
# Было загадано число 70
# Было загадано число 2
# Было загадано число 98
# Было загадано число 52
# Было загадано число 31
# Было загадано число 83
# Было загадано число 50
# Было загадано число 82
# Было загадано число 83
# Было загадано число 96
# Было загадано число 72
# Было загадано число 22
# Было загадано число 19
# Было загадано число 47
# Было загадано число 45
# Было загадано число 92
# Было загадано число 10
# Было загадано число 5
# Было загадано число 78
# Было загадано число 64
# Было загадано число 24
# Было загадано число 96
# Было загадано число 60
# Было загадано число 65
# Было загадано число 83
# Было загадано число 32
# Было загадано число 2
# Было загадано число 85
# Было загадано число 79
# Было загадано число 69
# Было загадано число 55
# Было загадано число 26
# Было загадано число 84
# Было загадано число 28
# Было загадано число 57
# Было загадано число 93
# Было загадано число 9
# Было загадано число 56
# Было загадано число 77
# Было загадано число 47
# Было загадано число 50
# Было загадано число 12
# Было загадано число 9
# Было загадано число 62
# Было загадано число 75
# Было загадано число 24
# Было загадано число 89
# Было загадано число 90
# Было загадано число 83
# Было загадано число 83
# Было загадано число 6
# Было загадано число 43
# Было загадано число 47
# Было загадано число 22
# Было загадано число 52
# Было загадано число 74
# Было загадано число 43
# Было загадано число 14
# Было загадано число 19
# Было загадано число 24
# Было загадано число 46
# Было загадано число 96
# Было загадано число 53
# Было загадано число 34
# Было загадано число 55
# Было загадано число 15
# Было загадано число 58
# Было загадано число 62
# Было загадано число 41
# Было загадано число 73
# Было загадано число 66
# Было загадано число 23
# Было загадано число 3
# Было загадано число 87
# Было загадано число 2
# Было загадано число 73
# Было загадано число 52
# Было загадано число 72
# Было загадано число 88
# Было загадано число 78
# Было загадано число 63
# Было загадано число 49
# Было загадано число 1
# Было загадано число 43
# Было загадано число 40
# Было загадано число 4
# Было загадано число 58
# Было загадано число 44
# Было загадано число 54
# Было загадано число 44
# Было загадано число 75
# Было загадано число 99
# Было загадано число 98
# Было загадано число 76
# Ваш алгоритм угадывает число в среднем за 6 попыток
